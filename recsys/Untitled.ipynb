# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm
# %pylab inline

import json
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(1.05)
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)
cset = ax.contour(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)

plt.show()

# %% [markdown]
# #get data

# %%
NAME = 'restaurants'
# NAME = 'beautyspa'
datapath = '../../data_recsys/'
path = datapath + NAME + '/'

# %%
#get data
infile = path+'specific_reviews_features.json'
from utils.featuresStructure import featureStructureWorker
fsw = featureStructureWorker()

X = [[j for j in range(101)] for i in range(101)]
Y = [[i for j in range(101)] for i in range(101)]
Z = [[pow(i+j,2) for j in range(101)] for i in range(101)]

# %%
reviews = list()
for counter, line in enumerate(open(r_file,'r')):
    review = json.loads(line)
    reviewFeatures = fsw.getReviewFeatures(review['features'])
    reviewFeatures['userID'] = review['user_id']
    reviewFeatures['bussID'] = review['business_id']
    
    reviews.append(reviewFeatures)
    
    if not counter%1000:
        print('%d reviews loaded'%counter)
        break

print('Reviews loaded')
print(reviews[0])

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
# X, Y, Z = axes3d.get_test_data(1.05)
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)
cset = ax.contour(X, Y, Z, zdir='z', offset=0, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=0, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=101, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(0, 101)
ax.set_ylabel('Y')
ax.set_ylim(0, 101)
ax.set_zlabel('Z')
ax.set_zlim(0, 40804)

plt.show()

# %%
testReviews = list()
for counter, line in enumerate(open(r_file,'r')):
    if not counter%1000:
        print('%d reviews loaded'%counter)
    testReviews.append(json.loads(line.strip()))
print('Reviews loaded')
# Out:
# array([[-30. , -19.5,  -9. ,   1.5,  12. ,  22.5],
#        [-30. , -19.5,  -9. ,   1.5,  12. ,  22.5],
#        [-30. , -19.5,  -9. ,   1.5,  12. ,  22.5],
#        [-30. , -19.5,  -9. ,   1.5,  12. ,  22.5],
#        [-30. , -19.5,  -9. ,   1.5,  12. ,  22.5],
#        [-30. , -19.5,  -9. ,   1.5,  12. ,  22.5]])

# %%
Y
# Out:
# array([[-30. , -30. , -30. , -30. , -30. , -30. ],
#        [-19.5, -19.5, -19.5, -19.5, -19.5, -19.5],
#        [ -9. ,  -9. ,  -9. ,  -9. ,  -9. ,  -9. ],
#        [  1.5,   1.5,   1.5,   1.5,   1.5,   1.5],
#        [ 12. ,  12. ,  12. ,  12. ,  12. ,  12. ],
#        [ 22.5,  22.5,  22.5,  22.5,  22.5,  22.5]])
